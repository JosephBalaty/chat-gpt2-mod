# %%
pip install torch
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# train a neural network to produce output like a trigram model.
names = open("names.txt", "r").read().splitlines()

# %%
# first we create our inputs and outputs by creating a 
#corresponding index table of the characters present in all the names.
names
chars = set(names)
chars
# Out:
# {'Colby',
#  'Cielo',
#  'Haylie',
#  'Lex',
#  'Antone',
#  'Enola',
#  'Novalee',
#  'Reginald',
#  'Alisson',
#  'Domingo',
#  'Savion',
#  'Manuela',
#  'Deena',
#  'Caden',
#  'Jordan',
#  'Frida',
#  'Chantel',
#  'Julie',
#  'Kale',
#  'Bettina',
#  'Shelli',
#  'Emmer',
#  'Mollie',
#  'Avayah',
#  'Rosina',
#  'Foster',
#  'Leigh',
#  'Najee',
#  'Khaleesi',
#  'Zariyah',
#  'Norbert',
#  'Kit',
#  'Chance',
#  'Teagan',
#  'Iyanna',
#  'Marge',
#  'Nanci',
#  'Theodis',
#  'Reno',
#  'Saylor',
#  'Belva',
#  'Brody',
#  'Coletta',
#  'Breanne',
#  'Cloe',
#  'Hamilton',
#  'Vickey',
#  'Iesha',
#  'Zaid',
#  'Campbell',
#  'Silas',
#  'Bree',
#  'Ennis',
#  'Enzo',
#  'Ishmael',
#  'Chaz',
#  'Louie',
#  'Khalid',
#  'Latanya',
#  'Bob',
#  'Ryley',
#  'Claire',
#  'Shanae',
#  'Brittny',
#  'Theadore',
#  'Lucero',
#  'Monika',
#  'Carey',
#  'Darryl',
#  'Aracely',
#  'Star',
#  'Lelia',
#  'Akeem',
#  'Ina',
#  'Kylo',
#  'Holly',
#  'Lynda',
#  'Arsenio',
#  'Della',
# ...
